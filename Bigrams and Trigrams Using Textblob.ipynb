# %%
from textblob import TextBlob

# %%
txt =TextBlob("""ఒకానొకప్పుడు ఒక ఊరిలో ఒక అమాయకపు పిచుక వుండేది. మనసులో ఏ కల్మషంలేని ఆ పిచుకకో ఒక రోజు ఒక కాకుల గుంపు పరిచయం అయ్యింది. ఆ కాకులతో పిచుకకి స్నేహం అయ్యింది. పిచుకకి అందరూ చెప్పారు – ఆ కాకులతో స్నేహం చేయద్దు, అవి మంచివి కావు, అని. కాని ఆ పిచుక మాట వినలేదు. ఒక రోజు కాకుల గుంపు ఎటో వెళ్తూ పిచుకను కూడా తోడు రమ్మన్నాయి. అమాయక పిచుక ఎక్కడకి, ఎందుకు అని అడగకుండా, ఆ కాకులను గుడ్డిగా నమ్మి వాటితో వెళ్ళింది. కాకులు ఒక పొలానికి వెళ్లి అక్కడ మొక్కలన్నిటిని ధ్వంసం చేయ సాగాయి. పిచుక నిస్సహాయంగా ఏమి చేయాలో తెలీకా అటూ ఇటూ గెంతుతూ వుంది. ఇంతలో ఆ పొలం రైతులు పరిగెత్తుకుంటూ వచ్చి ఒక పెద్ద కర్రతో ఆ కాకులను కొట్టడం మొదలెట్టారు. కాకుల గుంపుకు ఇది అలవాటే, అవి తుర్రున ఎగిరిపోయాయి. పిచుక రైతులకు దొరికిపోయింది. బాబోయ్ బాబోయ్ నా తప్పేమీ లేదు, నేను అమాయకురాలిని, నేనేమీ చేయలేదు, నన్ను వదిలేయండి అని పిచుక ప్రాధేయ పడింది. కాని పంట నాశనం అయిన రైతులు కోపం మీద ఉన్నారు. పిచుక మాట నమ్మలేదు కదా, దాని వైపు అసహ్యంగా చూసి మరో రెండు దెబ్బలు వేసారు. ఇతరులు మన మిత్రులను చూసి మన గుణం ఏమిటో నిర్దారించుకుంటారు. అందుకే మనం మంచి గా వున్న, మన స్నేహితులు చేడువారైతే మనం కూడా చెడ్డ వాళమనే అనుకుంటారు.""")

# %%
txt.words
# Out:
# WordList(['ఒకానొకప్పుడు', 'ఒక', 'ఊరిలో', 'ఒక', 'అమాయకపు', 'పిచుక', 'వుండేది', 'మనసులో', 'ఏ', 'కల్మషంలేని', 'ఆ', 'పిచుకకో', 'ఒక', 'రోజు', 'ఒక', 'కాకుల', 'గుంపు', 'పరిచయం', 'అయ్యింది', 'ఆ', 'కాకులతో', 'పిచుకకి', 'స్నేహం', 'అయ్యింది', 'పిచుకకి', 'అందరూ', 'చెప్పారు', '–', 'ఆ', 'కాకులతో', 'స్నేహం', 'చేయద్దు', 'అవి', 'మంచివి', 'కావు', 'అని', 'కాని', 'ఆ', 'పిచుక', 'మాట', 'వినలేదు', 'ఒక', 'రోజు', 'కాకుల', 'గుంపు', 'ఎటో', 'వెళ్తూ', 'పిచుకను', 'కూడా', 'తోడు', 'రమ్మన్నాయి', 'అమాయక', 'పిచుక', 'ఎక్కడకి', 'ఎందుకు', 'అని', 'అడగకుండా', 'ఆ', 'కాకులను', 'గుడ్డిగా', 'నమ్మి', 'వాటితో', 'వెళ్ళింది', 'కాకులు', 'ఒక', 'పొలానికి', 'వెళ్లి', 'అక్కడ', 'మొక్కలన్నిటిని', 'ధ్వంసం', 'చేయ', 'సాగాయి', 'పిచుక', 'నిస్సహాయంగా', 'ఏమి', 'చేయాలో', 'తెలీకా', 'అటూ', 'ఇటూ', 'గెంతుతూ', 'వుంది', 'ఇంతలో', 'ఆ', 'పొలం', 'రైతులు', 'పరిగెత్తుకుంటూ', 'వచ్చి', 'ఒక', 'పెద్ద', 'కర్రతో', 'ఆ', 'కాకులను', 'కొట్టడం', 'మొదలెట్టారు', 'కాకుల', 'గుంపుకు', 'ఇది', 'అలవాటే', 'అవి', 'తుర్రున', 'ఎగిరిపోయాయి', 'పిచుక', 'రైతులకు', 'దొరికిపోయింది', 'బాబోయ్', 'బాబోయ్', 'నా', 'తప్పేమీ', 'లేదు', 'నేను', 'అమాయకురాలిని', 'నేనేమీ', 'చేయలేదు', 'నన్ను', 'వదిలేయండి', 'అని', 'పిచుక', 'ప్రాధేయ', 'పడింది', 'కాని', 'పంట', 'నాశనం', 'అయిన', 'రైతులు', 'కోపం', 'మీద', 'ఉన్నారు', 'పిచుక', 'మాట', 'నమ్మలేదు', 'కదా', 'దాని', 'వైపు', 'అసహ్యంగా', 'చూసి', 'మరో', 'రెండు', 'దెబ్బలు', 'వేసారు', 'ఇతరులు', 'మన', 'మిత్రులను', 'చూసి', 'మన', 'గుణం', 'ఏమిటో', 'నిర్దారించుకుంటారు', 'అందుకే', 'మనం', 'మంచి', 'గా', 'వున్న', 'మన', 'స్నేహితులు', 'చేడువారైతే', 'మనం', 'కూడా', 'చెడ్డ', 'వాళమనే', 'అనుకుంటారు'])

# %%
txt.tags
# Out:
# [('ఒకానొకప్పుడు', 'JJ'),
#  ('ఒక', 'NNP'),
#  ('ఊరిలో', 'NNP'),
#  ('ఒక', 'NNP'),
#  ('అమాయకపు', 'NNP'),
#  ('పిచుక', 'NNP'),
#  ('వుండేది', 'NNP'),
#  ('మనసులో', 'JJ'),
#  ('ఏ', 'NNP'),
#  ('కల్మషంలేని', 'NNP'),
#  ('ఆ', 'NNP'),
#  ('పిచుకకో', 'NNP'),
#  ('ఒక', 'NNP'),
#  ('రోజు', 'NNP'),
#  ('ఒక', 'NNP'),
#  ('కాకుల', 'NNP'),
#  ('గుంపు', 'NNP'),
#  ('పరిచయం', 'NNP'),
#  ('అయ్యింది', 'NNP'),
#  ('ఆ', 'JJ'),
#  ('కాకులతో', 'NNP'),
#  ('పిచుకకి', 'NNP'),
#  ('స్నేహం', 'NNP'),
#  ('అయ్యింది', 'NNP'),
#  ('పిచుకకి', 'JJ'),
#  ('అందరూ', 'NNP'),
#  ('చెప్పారు', 'NNP'),
#  ('–', 'NNP'),
#  ('ఆ', 'NNP'),
#  ('కాకులతో', 'NNP'),
#  ('స్నేహం', 'NNP'),
#  ('చేయద్దు', 'NNP'),
#  ('అవి', 'NNP'),
#  ('మంచివి', 'NNP'),
#  ('కావు', 'NNP'),
#  ('అని', 'NNP'),
#  ('కాని', 'JJ'),
#  ('ఆ', 'NNP'),
#  ('పిచుక', 'NNP'),
#  ('మాట', 'NNP'),
#  ('వినలేదు', 'NNP'),
#  ('ఒక', 'JJ'),
#  ('రోజు', 'NNP'),
#  ('కాకుల', 'NNP'),
#  ('గుంపు', 'NNP'),
#  ('ఎటో', 'NNP'),
#  ('వెళ్తూ', 'NNP'),
#  ('పిచుకను', 'NNP'),
#  ('కూడా', 'NNP'),
#  ('తోడు', 'NNP'),
#  ('రమ్మన్నాయి', 'NNP'),
#  ('అమాయక', 'JJ'),
#  ('పిచుక', 'NNP'),
#  ('ఎక్కడకి', 'NNP'),
#  ('ఎందుకు', 'NNP'),
#  ('అని', 'NNP'),
#  ('అడగకుండా', 'NNP'),
#  ('ఆ', 'NNP'),
#  ('కాకులను', 'NNP'),
#  ('గుడ్డిగా', 'NNP'),
#  ('నమ్మి', 'NNP'),
#  ('వాటితో', 'NNP'),
#  ('వెళ్ళింది', 'NNP'),
#  ('కాకులు', 'JJ'),
#  ('ఒక', 'NNP'),
#  ('పొలానికి', 'NNP'),
#  ('వెళ్లి', 'NNP'),
#  ('అక్కడ', 'NNP'),
#  ('మొక్కలన్నిటిని', 'NNP'),
#  ('ధ్వంసం', 'NNP'),
#  ('చేయ', 'NNP'),
#  ('సాగాయి', 'NNP'),
#  ('పిచుక', 'JJ'),
#  ('నిస్సహాయంగా', 'NNP'),
#  ('ఏమి', 'NNP'),
#  ('చేయాలో', 'NNP'),
#  ('తెలీకా', 'NNP'),
#  ('అటూ', 'NNP'),
#  ('ఇటూ', 'NNP'),
#  ('గెంతుతూ', 'NNP'),
#  ('వుంది', 'NNP'),
#  ('ఇంతలో', 'JJ'),
#  ('ఆ', 'NNP'),
#  ('పొలం', 'NNP'),
#  ('రైతులు', 'NNP'),
#  ('పరిగెత్తుకుంటూ', 'NNP'),
#  ('వచ్చి', 'NNP'),
#  ('ఒక', 'NNP'),
#  ('పెద్ద', 'NNP'),
#  ('కర్రతో', 'NNP'),
#  ('ఆ', 'NNP'),
#  ('కాకులను', 'NNP'),
#  ('కొట్టడం', 'NNP'),
#  ('మొదలెట్టారు', 'NNP'),
#  ('కాకుల', 'JJ'),
#  ('గుంపుకు', 'NNP'),
#  ('ఇది', 'NNP'),
#  ('అలవాటే', 'NNP'),
#  ('అవి', 'NNP'),
#  ('తుర్రున', 'NNP'),
#  ('ఎగిరిపోయాయి', 'NNP'),
#  ('పిచుక', 'JJ'),
#  ('రైతులకు', 'NNP'),
#  ('దొరికిపోయింది', 'NNP'),
#  ('బాబోయ్', 'JJ'),
#  ('బాబోయ్', 'NNP'),
#  ('నా', 'NNP'),
#  ('తప్పేమీ', 'NNP'),
#  ('లేదు', 'NNP'),
#  ('నేను', 'NNP'),
#  ('అమాయకురాలిని', 'NNP'),
#  ('నేనేమీ', 'NNP'),
#  ('చేయలేదు', 'NNP'),
#  ('నన్ను', 'NNP'),
#  ('వదిలేయండి', 'NNP'),
#  ('అని', 'NNP'),
#  ('పిచుక', 'NNP'),
#  ('ప్రాధేయ', 'NNP'),
#  ('పడింది', 'NNP'),
#  ('కాని', 'JJ'),
#  ('పంట', 'NNP'),
#  ('నాశనం', 'NNP'),
#  ('అయిన', 'NNP'),
#  ('రైతులు', 'NNP'),
#  ('కోపం', 'NNP'),
#  ('మీద', 'NNP'),
#  ('ఉన్నారు', 'NNP'),
#  ('పిచుక', 'JJ'),
#  ('మాట', 'NNP'),
#  ('నమ్మలేదు', 'NNP'),
#  ('కదా', 'NNP'),
#  ('దాని', 'NNP'),
#  ('వైపు', 'NNP'),
#  ('అసహ్యంగా', 'NNP'),
#  ('చూసి', 'NNP'),
#  ('మరో', 'NNP'),
#  ('రెండు', 'NNP'),
#  ('దెబ్బలు', 'NNP'),
#  ('వేసారు', 'NNP'),
#  ('ఇతరులు', 'JJ'),
#  ('మన', 'NNP'),
#  ('మిత్రులను', 'NNP'),
#  ('చూసి', 'NNP'),
#  ('మన', 'NNP'),
#  ('గుణం', 'NNP'),
#  ('ఏమిటో', 'NNP'),
#  ('నిర్దారించుకుంటారు', 'NNP'),
#  ('అందుకే', 'JJ'),
#  ('మనం', 'NNP'),
#  ('మంచి', 'NNP'),
#  ('గా', 'NNP'),
#  ('వున్న', 'NNP'),
#  ('మన', 'NNP'),
#  ('స్నేహితులు', 'NNP'),
#  ('చేడువారైతే', 'NNP'),
#  ('మనం', 'NNP'),
#  ('కూడా', 'NNP'),
#  ('చెడ్డ', 'NNP'),
#  ('వాళమనే', 'NNP'),
#  ('అనుకుంటారు', 'NNP')]

# %%
txt.sentences
# Out:
# [Sentence("ఒకానొకప్పుడు ఒక ఊరిలో ఒక అమాయకపు పిచుక వుండేది."),
#  Sentence("మనసులో ఏ కల్మషంలేని ఆ పిచుకకో ఒక రోజు ఒక కాకుల గుంపు పరిచయం అయ్యింది."),
#  Sentence("ఆ కాకులతో పిచుకకి స్నేహం అయ్యింది."),
#  Sentence("పిచుకకి అందరూ చెప్పారు – ఆ కాకులతో స్నేహం చేయద్దు, అవి మంచివి కావు, అని."),
#  Sentence("కాని ఆ పిచుక మాట వినలేదు."),
#  Sentence("ఒక రోజు కాకుల గుంపు ఎటో వెళ్తూ పిచుకను కూడా తోడు రమ్మన్నాయి."),
#  Sentence("అమాయక పిచుక ఎక్కడకి, ఎందుకు అని అడగకుండా, ఆ కాకులను గుడ్డిగా నమ్మి వాటితో వెళ్ళింది."),
#  Sentence("కాకులు ఒక పొలానికి వెళ్లి అక్కడ మొక్కలన్నిటిని ధ్వంసం చేయ సాగాయి."),
#  Sentence("పిచుక నిస్సహాయంగా ఏమి చేయాలో తెలీకా అటూ ఇటూ గెంతుతూ వుంది."),
#  Sentence("ఇంతలో ఆ పొలం రైతులు పరిగెత్తుకుంటూ వచ్చి ఒక పెద్ద కర్రతో ఆ కాకులను కొట్టడం మొదలెట్టారు."),
#  Sentence("కాకుల గుంపుకు ఇది అలవాటే, అవి తుర్రున ఎగిరిపోయాయి."),
#  Sentence("పిచుక రైతులకు దొరికిపోయింది."),
#  Sentence("బాబోయ్ బాబోయ్ నా తప్పేమీ లేదు, నేను అమాయకురాలిని, నేనేమీ చేయలేదు, నన్ను వదిలేయండి అని పిచుక ప్రాధేయ పడింది."),
#  Sentence("కాని పంట నాశనం అయిన రైతులు కోపం మీద ఉన్నారు."),
#  Sentence("పిచుక మాట నమ్మలేదు కదా, దాని వైపు అసహ్యంగా చూసి మరో రెండు దెబ్బలు వేసారు."),
#  Sentence("ఇతరులు మన మిత్రులను చూసి మన గుణం ఏమిటో నిర్దారించుకుంటారు."),
#  Sentence("అందుకే మనం మంచి గా వున్న, మన స్నేహితులు చేడువారైతే మనం కూడా చెడ్డ వాళమనే అనుకుంటారు.")]

# %%
for sentence in txt.sentences:
    print(sentence.sentiment)
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
blob = TextBlob("మనసులో ఏ కల్మషంలేని ఆ పిచుకకో ఒక రోజు ఒక కాకుల గుంపు పరిచయం అయ్యింది. ఆ కాకులతో పిచుకకి స్నేహం అయ్యింది.")
blob.ngrams(n=2)
# Out:
# [WordList(['మనసులో', 'ఏ']),
#  WordList(['ఏ', 'కల్మషంలేని']),
#  WordList(['కల్మషంలేని', 'ఆ']),
#  WordList(['ఆ', 'పిచుకకో']),
#  WordList(['పిచుకకో', 'ఒక']),
#  WordList(['ఒక', 'రోజు']),
#  WordList(['రోజు', 'ఒక']),
#  WordList(['ఒక', 'కాకుల']),
#  WordList(['కాకుల', 'గుంపు']),
#  WordList(['గుంపు', 'పరిచయం']),
#  WordList(['పరిచయం', 'అయ్యింది']),
#  WordList(['అయ్యింది', 'ఆ']),
#  WordList(['ఆ', 'కాకులతో']),
#  WordList(['కాకులతో', 'పిచుకకి']),
#  WordList(['పిచుకకి', 'స్నేహం']),
#  WordList(['స్నేహం', 'అయ్యింది'])]

# %%
blob = TextBlob("మనసులో ఏ కల్మషంలేని ఆ పిచుకకో ఒక రోజు ఒక కాకుల గుంపు పరిచయం అయ్యింది. ఆ కాకులతో పిచుకకి స్నేహం అయ్యింది.")
blob.ngrams(n=3)
# Out:
# [WordList(['మనసులో', 'ఏ', 'కల్మషంలేని']),
#  WordList(['ఏ', 'కల్మషంలేని', 'ఆ']),
#  WordList(['కల్మషంలేని', 'ఆ', 'పిచుకకో']),
#  WordList(['ఆ', 'పిచుకకో', 'ఒక']),
#  WordList(['పిచుకకో', 'ఒక', 'రోజు']),
#  WordList(['ఒక', 'రోజు', 'ఒక']),
#  WordList(['రోజు', 'ఒక', 'కాకుల']),
#  WordList(['ఒక', 'కాకుల', 'గుంపు']),
#  WordList(['కాకుల', 'గుంపు', 'పరిచయం']),
#  WordList(['గుంపు', 'పరిచయం', 'అయ్యింది']),
#  WordList(['పరిచయం', 'అయ్యింది', 'ఆ']),
#  WordList(['అయ్యింది', 'ఆ', 'కాకులతో']),
#  WordList(['ఆ', 'కాకులతో', 'పిచుకకి']),
#  WordList(['కాకులతో', 'పిచుకకి', 'స్నేహం']),
#  WordList(['పిచుకకి', 'స్నేహం', 'అయ్యింది'])]

# %%
blob = TextBlob("మనసులో ఏ కల్మషంలేని ఆ పిచుకకో ఒక రోజు ఒక కాకుల గుంపు పరిచయం అయ్యింది. ఆ కాకులతో పిచుకకి స్నేహం అయ్యింది.")
blob.ngrams(n=4)
# Out:
# [WordList(['మనసులో', 'ఏ', 'కల్మషంలేని', 'ఆ']),
#  WordList(['ఏ', 'కల్మషంలేని', 'ఆ', 'పిచుకకో']),
#  WordList(['కల్మషంలేని', 'ఆ', 'పిచుకకో', 'ఒక']),
#  WordList(['ఆ', 'పిచుకకో', 'ఒక', 'రోజు']),
#  WordList(['పిచుకకో', 'ఒక', 'రోజు', 'ఒక']),
#  WordList(['ఒక', 'రోజు', 'ఒక', 'కాకుల']),
#  WordList(['రోజు', 'ఒక', 'కాకుల', 'గుంపు']),
#  WordList(['ఒక', 'కాకుల', 'గుంపు', 'పరిచయం']),
#  WordList(['కాకుల', 'గుంపు', 'పరిచయం', 'అయ్యింది']),
#  WordList(['గుంపు', 'పరిచయం', 'అయ్యింది', 'ఆ']),
#  WordList(['పరిచయం', 'అయ్యింది', 'ఆ', 'కాకులతో']),
#  WordList(['అయ్యింది', 'ఆ', 'కాకులతో', 'పిచుకకి']),
#  WordList(['ఆ', 'కాకులతో', 'పిచుకకి', 'స్నేహం']),
#  WordList(['కాకులతో', 'పిచుకకి', 'స్నేహం', 'అయ్యింది'])]
